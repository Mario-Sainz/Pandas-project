# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data5 = pd.read_csv('data5.csv')

# %%
data5
# Out:
#       Unnamed: 0         Date    Year        Type    Country             Area  \
# 0              0  25-Jun-2018  2018.0     Boating        USA       California
# 1              1  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2              2  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3              3  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4              4  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...          ...          ...     ...         ...        ...              ...
# 6304        6304            -       -           -          -                -
# 6305        6305            -       -           -          -                -
# 6306        6306            -       -           -          -                -
# 6307        6307            -       -           -          -                -
# 6308        6308            -       -           -          -                -
#
# ...

# %% [markdown]
# #### HIPÓTESIS

# %% [markdown]
# #### En USA han sido atacadas más mujeres que hombres por los ataques de tiburones. Esos ataques han sido causados por desastres marinos.

# %%
print(data5['Country'].value_counts())
# Out:
# USA                       2229
# AUSTRALIA                 1338
# SOUTH AFRICA               579
# PAPUA NEW GUINEA           134
# NEW ZEALAND                128
#                           ...
# RED SEA / INDIAN OCEAN       1
# PARAGUAY                     1
# SAN DOMINGO                  1
# COOK ISLANDS                 1
# MALDIVES                     1
# Name: Country, Length: 213, dtype: int64

# %%
data5[data5.Country=='USA'].Sex.mode()
# Out:
# 0    M
# dtype: object

# %%
data_f=data5[data5.Country=='USA']

# %%
data_f
# Out:
#       Unnamed: 0                Date    Year        Type Country  \
# 0              0         25-Jun-2018  2018.0     Boating     USA
# 1              1         18-Jun-2018  2018.0  Unprovoked     USA
# 2              2         09-Jun-2018  2018.0     Invalid     USA
# 7              7         27-May-2018  2018.0  Unprovoked     USA
# 8              8         26-May-2018  2018.0  Unprovoked     USA
# ...          ...                 ...     ...         ...     ...
# 6249        6249         Before 1958     0.0  Unprovoked     USA
# 6283        6283         Before 1921     0.0  Unprovoked     USA
# 6288        6288  Before 17-Jul-1916     0.0  Unprovoked     USA
# 6292        6292          Circa 1862     0.0  Unprovoked     USA
# 6299        6299           1900-1905     0.0  Unprovoked     USA
#
#                  Area                                           Location  \
# 0          California                        Oceanside, San Diego County
# ...

# %%
sns.countplot(x=data_f.Sex)
#Con esta gráfica podemos apreciar que en realidad nuestra hipótesis no es cierta.
#Han sido atacados más hombres que mujeres.
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
data5[data5.Country=='USA'].Type.mode()
# Out:
# 0    Unprovoked
# dtype: object

# %%
sns.countplot(x=data_f.Type)
#Con esta gráfica observamos que tampoco han sido causados principalmente por desastres marinos.
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>
